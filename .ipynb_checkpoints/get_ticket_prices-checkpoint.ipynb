# %%
import asyncio
asyncio.set_event_loop_policy(asyncio.WindowsSelectorEventLoopPolicy())

import nest_asyncio
nest_asyncio.apply()

from playwright.async_api import async_playwright

url = 'https://www.stubhub.com/'

async def scrape_stubhub():
    async with async_playwright() as p:
        browser = await p.chromium.launch(headless = False)
        page = await browser.new_page()
        
        await page.goto(url, timeout = 60000)
        await page.wait_for_selector('[data-testid="listing"]', timeout = 30000)
        listings = await page.query_selector_all('[data-testid="listing"]')
        
        results = []
        for listing in listings[:10]:
            title_el = await listing.query_selector('h3')
            price_el = await listing.query_selector('[data-testid="price"]')
            
            title = await title_el.inner_text() if title_el else None
            price = await price_el.inner_text() if price_el else None
            
            results.append({
                           'title': title,
                           'price': price
            })
        for r in results:
            print(r)
            
        await browser.close()
        
await scrape_stubhub()
# Out:
# Task exception was never retrieved
# future: <Task finished name='Task-3' coro=<Connection.run() done, defined at C:\Users\chris\AppData\Local\Programs\Python\Python39\lib\site-packages\playwright\_impl\_connection.py:305> exception=NotImplementedError()>
# Traceback (most recent call last):
#   File "C:\Users\chris\AppData\Local\Programs\Python\Python39\lib\site-packages\IPython\core\interactiveshell.py", line 3442, in run_code
#     await eval(code_obj, self.user_global_ns, self.user_ns)
#   File "C:\Users\chris\AppData\Local\Temp/ipykernel_15408/1207239913.py", line 37, in <module>
#     await scrape_stubhub()
#   File "C:\Users\chris\AppData\Local\Temp/ipykernel_15408/1207239913.py", line 12, in scrape_stubhub
#     async with async_playwright() as p:
#   File "C:\Users\chris\AppData\Local\Programs\Python\Python39\lib\site-packages\playwright\async_api\_context_manager.py", line 46, in __aenter__
#     playwright = AsyncPlaywright(next(iter(done)).result())
# ...
