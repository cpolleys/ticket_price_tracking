# %%
# !python results = scrape_stubhub_redsox.py
print(results)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_35188/4047482406.py in <module>
# ----> 1 results = scrape_stubhub_redsox.py
#       2 print(results)
#
# NameError: name 'scrape_stubhub_redsox' is not defined

# %%
# Save results for notebook
#with open("stubhub_data.json", "w") as f:
    #json.dump(results, f)
import pandas as pd
df = pd.read_json("stubhub_data.json")
df
# Out:
#                                    title  \
# 0  Boston Red Sox Tickets 2026 | StubHub
#
#                                                  url
# 0  https://www.stubhub.com/boston-red-sox-tickets...

# %%
print(df.url)
# Out:
# 0    https://www.stubhub.com/boston-red-sox-tickets...
# Name: url, dtype: object
