 'pixelRatio': 1, 'stretchX': [[30, 32], [42, 44]]}, 'dynamic-popover-light-amazing-deal-8': {'width': 74, 'height': 43, 'x': 222, 'y': 86, 'pixelRatio': 1, 'stretchX': [[30, 32], [42, 44]]}, 'dynamic-popover-light-amazing-deal-9': {'width': 74, 'height': 43, 'x': 148, 'y': 129, 'pixelRatio': 1, 'stretchX': [[30, 32], [42, 44]]}, 'dynamic-popover-light-taller': {'width': 54, 'height': 43, 'x': 222, 'y': 129, 'pixelRatio': 1, 'stretchX': [[8, 22], [32, 46]]}, 'poi-concession': {'width': 32, 'height': 32, 'x': 0, 'y': 172, 'pixelRatio': 1}, 'poi-restroom': {'width': 30, 'height': 32, 'x': 32, 'y': 172, 'pixelRatio': 1}, 'poi-shop': {'width': 32, 'height': 32, 'x': 62, 'y': 172, 'pixelRatio': 1}, 'dynamic-popover-dark': {'width': 54, 'height': 31, 'x': 94, 'y': 172, 'pixelRatio': 1, 'stretchX': [[8, 22], [32, 46]]}, 'dynamic-popover-light': {'width': 54, 'height': 31, 'x': 148, 'y': 172, 'pixelRatio': 1, 'stretchX': [[8, 22], [32, 46]]}, 'dynamic-popover-light-aisle': {'width': 64, 'height': 31, 'x': 202, 'y': 172, 'pixelRatio': 1, 'stretchX': [[22, 27], [37, 42]]}, 'dynamic-popover-light-bd': {'width': 64, 'height': 31, 'x': 0, 'y': 204, 'pixelRatio': 1, 'stretchX': [[22, 27], [37, 42]]}, 'dynamic-popover-light-bdv2': {'width': 64, 'height': 31, 'x': 64, 'y': 204, 'pixelRatio': 1, 'stretchX': [[22, 27], [37, 42]]}, 'dynamic-popover-light-bv': {'width': 64, 'height': 31, 'x': 128, 'y': 204, 'pixelRatio': 1, 'stretchX': [[22, 27], [37, 42]]}, 'dynamic-popover-light-cheapest': {'width': 64, 'height': 31, 'x': 192, 'y': 204, 'pixelRatio': 1, 'stretchX': [[22, 27], [37, 42]]}, 'dynamic-popover-light-flame': {'width': 64, 'height': 31, 'x': 0, 'y': 235, 'pixelRatio': 1, 'stretchX': [[22, 27], [37, 42]]}, 'dynamic-popover-light-hidden-gem': {'width': 64, 'height': 31, 'x': 64, 'y': 235, 'pixelRatio': 1, 'stretchX': [[22, 27], [37, 42]]}, 'dynamic-popover-light-id': {'width': 64, 'height': 31, 'x': 128, 'y': 235, 'pixelRatio': 1, 'stretchX': [[22, 27], [37, 42]]}, 'poi-exit': {'width': 30, 'height': 30, 'x': 256, 'y': 204, 'pixelRatio': 1}}
# {'c': 'YBn4MAQ+/do=', 'd': 3, 'v': '2'}
# {'status': 'success'}

# %%
# Save results for notebook
#with open("stubhub_data.json", "w") as f:
    #json.dump(results, f)
import pandas as pd
df = pd.read_json("stubhub_data.json")
df
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_13796/792337694.py in <module>
#       3     #json.dump(results, f)
#       4 import pandas as pd
# ----> 5 df = pd.read_json("stubhub_data.json")
#       6 df
#
# ~\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\io\json\_json.py in read_json(path_or_buf, orient, typ, dtype, convert_axes, convert_dates, keep_default_dates, precise_float, date_unit, encoding, encoding_errors, lines, chunksize, compression, nrows, storage_options, dtype_backend, engine)
#     789         convert_axes = True
#     790
# --> 791     json_reader = JsonReader(
#     792         path_or_buf,
#     793         orient=orient,
#
# ~\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\io\json\_json.py in __init__(self, filepath_or_buffer, orient, typ, dtype, convert_axes, convert_dates, keep_default_dates, precise_float, date_unit, encoding, lines, chunksize, compression, nrows, storage_options, encoding_errors, dtype_backend, engine)
#     902             self.data = filepath_or_buffer
#     903         elif self.engine == "ujson":
# --> 904             data = self._get_data_from_filepath(filepath_or_buffer)
#     905             self.data = self._preprocess_data(data)
#     906
#
# ~\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\io\json\_json.py in _get_data_from_filepath(self, filepath_or_buffer)
#     958             and not file_exists(filepath_or_buffer)
#     959         ):
# --> 960             raise FileNotFoundError(f"File {filepath_or_buffer} does not exist")
#     961         else:
#     962             warnings.warn(
#
# FileNotFoundError: File stubhub_data.json does not exist

# %%
print(df.url)
# Out:
# 0    https://www.stubhub.com/boston-red-sox-tickets...
# Name: url, dtype: object
