# %%
# !python scrape_stubhub_redsox.py
# Out:
# Exception in callback AsyncIOEventEmitter._emit_run.<locals>.callback(<Task finishe...not defined")>) at C:\Users\chris\AppData\Local\Programs\Python\Python39\lib\site-packages\pyee\asyncio.py:97
# handle: <Handle AsyncIOEventEmitter._emit_run.<locals>.callback(<Task finishe...not defined")>) at C:\Users\chris\AppData\Local\Programs\Python\Python39\lib\site-packages\pyee\asyncio.py:97>
# Traceback (most recent call last):
#   File "C:\Users\chris\AppData\Local\Programs\Python\Python39\lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "C:\Users\chris\AppData\Local\Programs\Python\Python39\lib\site-packages\pyee\asyncio.py", line 105, in callback
#     self.emit("error", exc)
#   File "C:\Users\chris\AppData\Local\Programs\Python\Python39\lib\site-packages\pyee\asyncio.py", line 70, in emit
#     return super().emit(event, *args, **kwargs)
# ...

# %%
# Save results for notebook
#with open("stubhub_data.json", "w") as f:
    #json.dump(results, f)
import pandas as pd
df = pd.read_json("stubhub_data.json")
df
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_13796/792337694.py in <module>
#       3     #json.dump(results, f)
#       4 import pandas as pd
# ----> 5 df = pd.read_json("stubhub_data.json")
#       6 df
#
# ~\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\io\json\_json.py in read_json(path_or_buf, orient, typ, dtype, convert_axes, convert_dates, keep_default_dates, precise_float, date_unit, encoding, encoding_errors, lines, chunksize, compression, nrows, storage_options, dtype_backend, engine)
#     789         convert_axes = True
#     790
# --> 791     json_reader = JsonReader(
#     792         path_or_buf,
#     793         orient=orient,
#
# ...

# %%
print(df.url)
# Out:
# 0    https://www.stubhub.com/boston-red-sox-tickets...
# Name: url, dtype: object
